# %% [markdown]
# # Cáncer de mama a través de los datos

# %% [markdown]
# ## Tema
#
# ### Exploración de los datos epidemiológicos del cáncer de mama para identificar patrones y factores relevantes que influyen en la incidencia, el diagnóstico y la supervivencia. Este análisis busca destacar la importancia del diagnóstico temprano y cómo diferentes factores pueden impactar los resultados de los tratamientos.
#
# ## Hipótesis
#
# ### El diagnóstico temprano mejora significativamente la supervivencia en pacientes con cáncer de mama.
#
# ### El tipo de prueba diagnóstica tiene un impacto significativo en la tasa de detección temprana.
#
# ###  La incidencia y la supervivencia del cáncer de mama están influenciadas por factores demográficos como la raza y la etnicidad.
#
# ###  El tamaño del tumor al momento del diagnóstico es un predictor clave de la supervivencia.
#
# ### El estatus hormonal (ER+/PR+) afecta la supervivencia y la mortalidad en pacientes con cáncer de mama.

# %%
import pandas as pd
df_1 = pd.read_csv("C:/Users/JUTHA/Documents/bootcamp Base de datos/Bootcamp_bases_de_datos/SEER Breast Cancer Dataset .csv")

# %% [markdown]
# ## Fuente
#
# ### "SEER Breast Cancer Dataset: Obtained in 2017 from patients diagnosed in 2006-2010"

# %%
df_1.head()
# Out:
#                                                  Age     Race   \
# 0  43,"Other (American Indian/AK Native, Asian/Pa...  Regional
# 1  47,"Other (American Indian/AK Native, Asian/Pa...  Regional
# 2                                                 67     White
# 3                                                 46     White
# 4                                                 63     White
#
#                    Marital Status Unnamed: 3  T Stage  N Stage 6th Stage  \
# 0                              40   Positive  Positive      19        11
# 1                              45   Positive  Positive      25         9
# 2  Married (including common law)        NaN        T2      N1       IIB
# 3                        Divorced        NaN        T1      N1       IIA
# 4  Married (including common law)        NaN        T2      N2      IIIA
#
#                                  Grade   A Stage  Tumor Size Estrogen Status  \
# ...

# %%
df_1.tail()
# Out:
#                                                     Age     Race   \
# 4019                                                 52     White
# 4020                                                 53     White
# 4021                                                 53     White
# 4022  60,"Other (American Indian/AK Native, Asian/Pa...  Regional
# 4023                                                 62     White
#
#                       Marital Status Unnamed: 3  T Stage  N Stage 6th Stage  \
# 4019  Married (including common law)        NaN        T1      N1       IIA
# 4020  Married (including common law)        NaN        T1      N2      IIIA
# 4021                        Divorced        NaN        T1      N1       IIA
# 4022                               9   Positive  Positive      14         2
# 4023                        Divorced        NaN        T1      N1       IIA
#
#                                     Grade   A Stage  Tumor Size  \
# ...
